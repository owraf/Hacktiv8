# %% [markdown]
# **MOCHAMAD RAFFLI ISPRIYANTO** PYTN-KS10-022

# %% [markdown]
# H0 : Jumlah kriminalitas di Kota London berebanding lurus dengan seiring bertambahnya waktu per tahun?

# %% [markdown]
# H1 : Jumlah kriminalitas di Kota London berbanding terbalik seiring bertambahnya waktu per tahun?

# %%
# mengimport library yang dibutuhkan
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from wordcloud import WordCloud, STOPWORDS

# %%
df = pd.read_csv('london_crime_by_lsoa.zip')
df
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
df.shape
# Out:
# (13490604, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13490604 entries, 0 to 13490603
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   lsoa_code       object
#  1   borough         object
#  2   major_category  object
#  3   minor_category  object
#  4   value           int64
#  5   year            int64
#  6   month           int64
# dtypes: int64(3), object(4)
# memory usage: 720.5+ MB

# %%
kriminalitas = df[df['value'] >= 1] 
kriminalitas
# Out:
#           lsoa_code               borough               major_category  \
# 9         E01004177                Sutton           Theft and Handling
# 16        E01000086  Barking and Dagenham           Theft and Handling
# 24        E01001301                Ealing           Theft and Handling
# 25        E01001794               Hackney  Violence Against the Person
# 32        E01000733               Bromley              Criminal Damage
# ...             ...                   ...                          ...
# 13490581  E01000789               Bromley  Violence Against the Person
# 13490584  E01003301              Lewisham  Violence Against the Person
# 13490590  E01001679             Greenwich           Theft and Handling
# 13490592  E01033327              Lewisham  Violence Against the Person
# 13490600  E01002504            Hillingdon                      Robbery
#
#                             minor_category  value  year  month
# ...

# %%
kriminalitas8 = kriminalitas[kriminalitas['year'] == 2008] 
kriminalitas9 = kriminalitas[kriminalitas['year'] == 2009] 
kriminalitas10 = kriminalitas[kriminalitas['year'] == 2010]
kriminalitas11 = kriminalitas[kriminalitas['year'] == 2011]
kriminalitas12 = kriminalitas[kriminalitas['year'] == 2012]
kriminalitas13 = kriminalitas[kriminalitas['year'] == 2013] 
kriminalitas14 = kriminalitas[kriminalitas['year'] == 2014]
kriminalitas15 = kriminalitas[kriminalitas['year'] == 2015]
kriminalitas16 = kriminalitas[kriminalitas['year'] == 2016]

# %%
sum8 = kriminalitas8['value'].sum() 
sum9 = kriminalitas9['value'].sum()
sum10 = kriminalitas10['value'].sum()
sum11 = kriminalitas11['value'].sum()
sum12 = kriminalitas12['value'].sum()
sum13 = kriminalitas13['value'].sum()
sum14 = kriminalitas14['value'].sum()
sum15 = kriminalitas15['value'].sum()
sum16 = kriminalitas16['value'].sum()

# %%
df.drop('lsoa_code', axis=1, inplace=True)
df.head()
# Out:
#       borough               major_category               minor_category  \
# 0     Croydon                     Burglary  Burglary in Other Buildings
# 1   Greenwich  Violence Against the Person               Other violence
# 2     Bromley  Violence Against the Person               Other violence
# 3   Redbridge                     Burglary  Burglary in Other Buildings
# 4  Wandsworth                      Robbery            Personal Property
#
#    value  year  month
# 0      0  2016     11
# 1      0  2016     11
# 2      0  2015      5
# 3      0  2016      3
# 4      0  2008      6

# %% [markdown]
# **PERTANYAAN 1** : Berapa jumlah kasus kriminal di London pada tahun 2008 sampai 2016?

# %% [markdown]
# **LINE PLOT**

# %%
df_1 = kriminalitas[kriminalitas['year'] >= 2008]
df_1
# Out:
#           lsoa_code               borough               major_category  \
# 9         E01004177                Sutton           Theft and Handling
# 16        E01000086  Barking and Dagenham           Theft and Handling
# 24        E01001301                Ealing           Theft and Handling
# 25        E01001794               Hackney  Violence Against the Person
# 32        E01000733               Bromley              Criminal Damage
# ...             ...                   ...                          ...
# 13490581  E01000789               Bromley  Violence Against the Person
# 13490584  E01003301              Lewisham  Violence Against the Person
# 13490590  E01001679             Greenwich           Theft and Handling
# 13490592  E01033327              Lewisham  Violence Against the Person
# 13490600  E01002504            Hillingdon                      Robbery
#
#                             minor_category  value  year  month
# ...

# %%
df_1.drop(['borough','major_category','minor_category'], axis=1, inplace=True)
df_1
# Out:
#           lsoa_code  value  year  month
# 9         E01004177      1  2016      8
# 16        E01000086      1  2009      5
# 24        E01001301      2  2012      1
# 25        E01001794      1  2013      2
# 32        E01000733      1  2016      4
# ...             ...    ...   ...    ...
# 13490581  E01000789      3  2009     12
# 13490584  E01003301      1  2015     10
# 13490590  E01001679      1  2012      4
# 13490592  E01033327      2  2013      7
# 13490600  E01002504      1  2015      6
#
# [3419099 rows x 4 columns]

# %%
plt.plot(['2008', '2009', '2010', '2011', '2012','2013', '2014', '2015', '2016'], 
         [sum8, sum9, sum10, sum11, sum12, sum13, sum14, sum15, sum16])

plt.ylabel('Jumlah Kriminalitas')
plt.xlabel('Tahun')
plt.title('Jumlah kriminalitas di London pada tahun 2008 sampai 2016')
# Out:
# Text(0.5, 1.0, 'Jumlah kriminalitas di London pada tahun 2008 sampai 2016')

# %% [markdown]
# **AREA PLOT**

# %%
area_array = np.array([['2008', '2009', '2010', '2011', '2012','2013', '2014', '2015', '2016'],
                      [sum8, sum9, sum10, sum11, sum12, sum13, sum14, sum15, sum16]])

area_array = area_array.T
area_array
# Out:
# array([['2008', '738641'],
#        ['2009', '717214'],
#        ['2010', '715324'],
#        ['2011', '724915'],
#        ['2012', '737329'],
#        ['2013', '686407'],
#        ['2014', '680183'],
#        ['2015', '711624'],
#        ['2016', '736121']], dtype='<U21')

# %%
df_1 = pd.DataFrame(area_array, columns = ['tahun', 'jumlah kriminalitas'])
df_1.sort_values('tahun')
# Out:
#   tahun jumlah kriminalitas
# 0  2008              738641
# 1  2009              717214
# 2  2010              715324
# 3  2011              724915
# 4  2012              737329
# 5  2013              686407
# 6  2014              680183
# 7  2015              711624
# 8  2016              736121

# %%
df_1.set_index('tahun', inplace=True)

# %%
df_1.index = df_1.index.map(str)
df_1['jumlah kriminalitas'] = df_1['jumlah kriminalitas'].map(int)

# %%
df_1.plot(kind='area',
          stacked = False,
          figsize=(10,5),
          color='grey',)

plt.title('Jumlah kriminalitas di London pada tahun 2013 sampai 2016')
plt.ylabel('Jumlah Kriminalitas')
plt.xlabel('Tahun')
# Out:
# Text(0.5, 0, 'Tahun')

# %% [markdown]
# Dari line plot dan area plot diatas dapat disimpulkan bahwa kasus kejahatan di kota London cenderung naik seiring bertambahnya waktu.

# %% [markdown]
# **PERTANYAAN 2** : Berapa frekuensi wilayah dengan 5 kejahatan teratas di tahun 2013?

# %% [markdown]
# **BAR CHART**

# %%
df_2 = df[df['year'] == 2013]
df_2
# Out:
#                  borough               major_category  \
# 7               Hounslow                      Robbery
# 8                 Newham              Criminal Damage
# 10              Haringey           Theft and Handling
# 25               Hackney  Violence Against the Person
# 30                Ealing                     Burglary
# ...                  ...                          ...
# 13490547  Waltham Forest  Violence Against the Person
# 13490571           Brent                     Burglary
# 13490572       Greenwich              Criminal Damage
# 13490578        Hounslow  Violence Against the Person
# 13490592        Lewisham  Violence Against the Person
#
#                                   minor_category  value  year  month
# 7                              Personal Property      0  2013      4
# 8              Criminal Damage To Other Building      0  2013      9
# 10        Motor Vehicle Interference & Tampering      0  2013     12
# ...

# %%
df_2 = df_2.sort_values(by='borough')
df_2
# Out:
#                        borough               major_category  \
# 6055417   Barking and Dagenham           Theft and Handling
# 9126148   Barking and Dagenham                     Burglary
# 3147370   Barking and Dagenham           Theft and Handling
# 6988118   Barking and Dagenham           Theft and Handling
# 8343516   Barking and Dagenham  Violence Against the Person
# ...                        ...                          ...
# 8423601            Westminster                        Drugs
# 2644487            Westminster                      Robbery
# 5408162            Westminster              Criminal Damage
# 9121594            Westminster    Other Notifiable Offences
# 11747424           Westminster              Criminal Damage
#
#                             minor_category  value  year  month
# 6055417                   Theft From Shops      0  2013     10
# 9126148             Burglary in a Dwelling      0  2013     11
# ...

# %%
df_2.drop(['major_category','minor_category','month'], axis=1, inplace=True)
df_2
# Out:
#                        borough  value  year
# 6055417   Barking and Dagenham      0  2013
# 9126148   Barking and Dagenham      0  2013
# 3147370   Barking and Dagenham      0  2013
# 6988118   Barking and Dagenham      1  2013
# 8343516   Barking and Dagenham      2  2013
# ...                        ...    ...   ...
# 8423601            Westminster      0  2013
# 2644487            Westminster      0  2013
# 5408162            Westminster      0  2013
# 9121594            Westminster      0  2013
# 11747424           Westminster      0  2013
#
# [1498956 rows x 3 columns]

# %%
kriminalitas_2 = kriminalitas[kriminalitas['year'] == 2013]
kriminalitas_2
# Out:
#           lsoa_code               borough               major_category  \
# 25        E01001794               Hackney  Violence Against the Person
# 97        E01004142                Sutton                     Burglary
# 121       E01000045  Barking and Dagenham                      Robbery
# 187       E01004654           Westminster           Theft and Handling
# 371       E01000188                Barnet  Violence Against the Person
# ...             ...                   ...                          ...
# 13490474  E01004330        Waltham Forest           Theft and Handling
# 13490482  E01001112               Croydon                        Drugs
# 13490500  E01002333              Havering           Theft and Handling
# 13490572  E01033735             Greenwich              Criminal Damage
# 13490592  E01033327              Lewisham  Violence Against the Person
#
#                                   minor_category  value  year  month
# ...

# %%
df_2_top5 = kriminalitas_2['borough'].value_counts().head()
df_2_top5
# Out:
# Lambeth      16357
# Southwark    16058
# Croydon      15530
# Ealing       14729
# Newham       14678
# Name: borough, dtype: int64

# %%
wilayah = ['Lambeth', 'Southwark', 'Croydon', 'Ealing', 'Newham']
jumlah_kriminalitas  = [16357, 16058, 15530, 14729, 14678]

plt.bar(wilayah, jumlah_kriminalitas, color='magenta')
plt.title('Frekuensi wilayah dengan 5 kejahatan teratas di tahun 2013', size=12)
plt.ylabel('Jumlah Kriminalitas', size=14)
plt.xlabel('Wilayah', size=14)
plt.xticks(size=10)
plt.yticks(size=10)

plt.show()

# %% [markdown]
# Dari barchart diatas dapat ditarik kesimpulan bahwa 5 wilayah yang paling banyak kasus kriminalitas di Kota London pada tahun 2013 adalah wilayah Lambeth dengan 16357 kasus. Peringkat kedua ditempati oleh Southwark dengan 16058 kasus, yang ketiga adalah Croydon dengan 15530 kasus, yang keempat adalah wilayah Ealing dengan 14729 kasus dan yang terakhir ditempati oleh Newham dengan 14678 kasus kriminalitas.

# %% [markdown]
# **PERTANYAAN 3** : Bagaimana distribusi kasus kriminal di London pada tahun 2010 sampai 2016?

# %% [markdown]
# **HISTOGRAM**

# %%
df_3 = kriminalitas[kriminalitas['year'] >= 2010]
df_3
# Out:
#           lsoa_code     borough               major_category  \
# 9         E01004177      Sutton           Theft and Handling
# 24        E01001301      Ealing           Theft and Handling
# 25        E01001794     Hackney  Violence Against the Person
# 32        E01000733     Bromley              Criminal Damage
# 43        E01001193     Croydon           Theft and Handling
# ...             ...         ...                          ...
# 13490580  E01003154     Lambeth                     Burglary
# 13490584  E01003301    Lewisham  Violence Against the Person
# 13490590  E01001679   Greenwich           Theft and Handling
# 13490592  E01033327    Lewisham  Violence Against the Person
# 13490600  E01002504  Hillingdon                      Robbery
#
#                             minor_category  value  year  month
# 9              Theft/Taking of Pedal Cycle      1  2016      8
# 24                      Other Theft Person      2  2012      1
# ...

# %%
df_3.drop(['month','lsoa_code','borough','major_category','minor_category'], axis=1, inplace=True)
df_3
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_51948\2195223551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3.drop(['month','lsoa_code','borough','major_category','minor_category'], axis=1, inplace=True)
#           value  year
# 9             1  2016
# 24            2  2012
# 25            1  2013
# 32            1  2016
# 43            1  2014
# ...         ...   ...
# 13490580      3  2015
# 13490584      1  2015
# 13490590      1  2012
# 13490592      2  2013
# 13490600      1  2015
#
# [2644849 rows x 2 columns]

# %%
df_3.sort_values('year')
# Out:
#           value  year
# 6750870       1  2010
# 12880867      1  2010
# 4388518       1  2010
# 9060578       1  2010
# 4388526       3  2010
# ...         ...   ...
# 11500419      2  2016
# 5810728       1  2016
# 11500394      1  2016
# 11500634      3  2016
# 9             1  2016
#
# [2644849 rows x 2 columns]

# %%
my_array = np.array([['2010', '2011', '2012', '2013', '2014', '2015', '2016'], 
                     [sum10, sum11, sum12, sum13, sum14, sum15, sum16]])
my_array = my_array.T
my_array
# Out:
# array([['2010', '715324'],
#        ['2011', '724915'],
#        ['2012', '737329'],
#        ['2013', '686407'],
#        ['2014', '680183'],
#        ['2015', '711624'],
#        ['2016', '736121']], dtype='<U21')

# %%
df_3 = pd.DataFrame(my_array, columns = ['tahun', 'jumlah_kriminalitas'])
df_3
# Out:
#   tahun jumlah_kriminalitas
# 0  2010              715324
# 1  2011              724915
# 2  2012              737329
# 3  2013              686407
# 4  2014              680183
# 5  2015              711624
# 6  2016              736121

# %%
df_3.set_index('tahun', inplace=True)
df_3
# Out:
#       jumlah_kriminalitas
# tahun
# 2010               715324
# 2011               724915
# 2012               737329
# 2013               686407
# 2014               680183
# 2015               711624
# 2016               736121

# %%
df_3.index = df_3.index.map(str)
df_3['jumlah_kriminalitas'] = df_3['jumlah_kriminalitas'].map(int)

plt.figure()
df_3['jumlah_kriminalitas'].plot.hist()
plt.xlabel('Jumlah kriminalitas')
plt.title('Jumlah Kriminalitas', size=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# Dari histogram diatas didapatkan kesimpulan bahwa jumlah kriminalitas 736121 sampai 737329 memiliki frekuensi paling tinggi yaitu sebanyak 2.00

# %% [markdown]
# **PERTANYAAN 4** : Wilayah apa yang memiliki kasus kriminalitas terbanyak di kota London pada tahun 2014?

# %% [markdown]
# **WORDCLOUD**

# %%
df_4 = kriminalitas[kriminalitas['year'] == 2014]
df_4
# Out:
#           lsoa_code        borough               major_category  \
# 43        E01001193        Croydon           Theft and Handling
# 99        E01000223         Barnet  Violence Against the Person
# 120       E01001170        Croydon  Violence Against the Person
# 134       E01004674    Westminster           Theft and Handling
# 159       E01004033      Southwark           Theft and Handling
# ...             ...            ...                          ...
# 13490377  E01004303  Tower Hamlets           Theft and Handling
# 13490403  E01000174         Barnet  Violence Against the Person
# 13490416  E01000696        Bromley  Violence Against the Person
# 13490454  E01000729        Bromley              Criminal Damage
# 13490505  E01002290       Havering                     Burglary
#
#                                   minor_category  value  year  month
# 43                                   Other Theft      1  2014      5
# ...

# %%
df_4.drop(['month','lsoa_code','year','major_category','minor_category','value'], axis=1, inplace=True)
df_4
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_51948\3609820460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4.drop(['month','lsoa_code','year','major_category','minor_category','value'], axis=1, inplace=True)
#                 borough
# 43              Croydon
# 99               Barnet
# 120             Croydon
# 134         Westminster
# 159           Southwark
# ...                 ...
# 13490377  Tower Hamlets
# 13490403         Barnet
# 13490416        Bromley
# 13490454        Bromley
# 13490505       Havering
#
# [370384 rows x 1 columns]

# %%
df_4.to_csv('df_4.csv')

# %%
df_4.to_csv('df_4.txt', sep='\t')

# %%
df_4_1 = open('df_4.txt', 'r').read()

# %%
stopwords = set(STOPWORDS)

# %%
stopwords.add('borough')
# inisiasi wordcloud
krim_2014 = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate wordcloud
krim_2014.generate(df_4_1)

# %%
plt.figure(figsize=(20,10))
plt.imshow(krim_2014, interpolation='bilinear');
plt.axis('off');

# %% [markdown]
# Dari wordcloud diatas wilayah memiliki kasus kriminalitas terbanyak di kota London pada tahun 2014 adalah Islington dan Hillingdon

# %% [markdown]
# **PERTANYAAN 5** : Berapa banyak kriminalitas dengan kategori Harassment dari tahun 2012 sampai 2016?

# %% [markdown]
# **SCATTER PLOT**

# %%
df_5 = kriminalitas[kriminalitas['year'] >= 2012]
df_5
# Out:
#           lsoa_code     borough               major_category  \
# 9         E01004177      Sutton           Theft and Handling
# 24        E01001301      Ealing           Theft and Handling
# 25        E01001794     Hackney  Violence Against the Person
# 32        E01000733     Bromley              Criminal Damage
# 43        E01001193     Croydon           Theft and Handling
# ...             ...         ...                          ...
# 13490580  E01003154     Lambeth                     Burglary
# 13490584  E01003301    Lewisham  Violence Against the Person
# 13490590  E01001679   Greenwich           Theft and Handling
# 13490592  E01033327    Lewisham  Violence Against the Person
# 13490600  E01002504  Hillingdon                      Robbery
#
#                             minor_category  value  year  month
# 9              Theft/Taking of Pedal Cycle      1  2016      8
# 24                      Other Theft Person      2  2012      1
# ...

# %%
df_5.drop(['month', 'borough','lsoa_code','major_category'], axis=1, inplace=True)
df_5
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_51948\372485351.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_5.drop(['month', 'borough','lsoa_code','major_category'], axis=1, inplace=True)
#                             minor_category  value  year
# 9              Theft/Taking of Pedal Cycle      1  2016
# 24                      Other Theft Person      2  2012
# 25                              Harassment      1  2013
# 32        Criminal Damage To Motor Vehicle      1  2016
# 43                             Other Theft      1  2014
# ...                                    ...    ...   ...
# 13490580            Burglary in a Dwelling      3  2015
# 13490584               Assault with Injury      1  2015
# 13490590     Theft/Taking Of Motor Vehicle      1  2012
# ...

# %%
df_5 = df_5[df_5['minor_category'] == 'Harassment']
df_5
# Out:
#          minor_category  value  year
# 25           Harassment      1  2013
# 95           Harassment      1  2012
# 99           Harassment      1  2014
# 270          Harassment      1  2012
# 345          Harassment      1  2016
# ...                 ...    ...   ...
# 13490297     Harassment      2  2015
# 13490327     Harassment      2  2015
# 13490416     Harassment      1  2014
# 13490538     Harassment      5  2016
# 13490560     Harassment      1  2015
#
# [150652 rows x 3 columns]

# %%
df_5['year'].value_counts()
# Out:
# 2016    36213
# 2015    34556
# 2014    29677
# 2012    25355
# 2013    24851
# Name: year, dtype: int64

# %%
x = ['2013', '2012', '2014', '2015', '2016']
y = ['24851', '25355','29677','34556','36213']
plt.scatter(x, y)
plt.title('Jumlah kasus kriminalitas di Lodon pada Tahun 2012 sampai 2016', size=12)
plt.ylabel('Jumlah Kriminalitas', size=14)
plt.xlabel('tahun', size=14)
plt.show()

# %% [markdown]
# Dari scatter plot diatas dapat disimpulkan bahwa kasus kejahatan di kota London cenderung naik seiring bertambahnya waktu. Hal tersebut dapat dibuktikan kasus pada tahun 2012 mengalami penurunan hingga tahun 2013 kemudian kembali naik hingga tahun 2016

# %% [markdown]
# **PERTANYAAN 6** : Berapa persentase kriminalitas dengan kategori mayor pada tahun 2014 di Seluruh wilayah London?

# %% [markdown]
# **PIE CHART**

# %%
df_6 = kriminalitas[kriminalitas['year'] == 2014]
df_6
# Out:
#           lsoa_code        borough               major_category  \
# 43        E01001193        Croydon           Theft and Handling
# 99        E01000223         Barnet  Violence Against the Person
# 120       E01001170        Croydon  Violence Against the Person
# 134       E01004674    Westminster           Theft and Handling
# 159       E01004033      Southwark           Theft and Handling
# ...             ...            ...                          ...
# 13490377  E01004303  Tower Hamlets           Theft and Handling
# 13490403  E01000174         Barnet  Violence Against the Person
# 13490416  E01000696        Bromley  Violence Against the Person
# 13490454  E01000729        Bromley              Criminal Damage
# 13490505  E01002290       Havering                     Burglary
#
#                                   minor_category  value  year  month
# 43                                   Other Theft      1  2014      5
# ...

# %%
df_6.drop(['month','lsoa_code','borough','year','minor_category'], axis=1, inplace=True)
df_6
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_51948\764483916.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_6.drop(['month','lsoa_code','borough','year','minor_category'], axis=1, inplace=True)
#                        major_category  value
# 43                 Theft and Handling      1
# 99        Violence Against the Person      1
# 120       Violence Against the Person      1
# 134                Theft and Handling      1
# 159                Theft and Handling      1
# ...                               ...    ...
# 13490377           Theft and Handling      3
# 13490403  Violence Against the Person      1
# 13490416  Violence Against the Person      1
# 13490454              Criminal Damage      1
# 13490505                     Burglary      1
#
# [370384 rows x 2 columns]

# %%
df_6 = df_6['major_category'].value_counts()

# %%
df_6.plot(kind='pie',
            figsize=(20,18),
            autopct="%.2f%%",
            startangle=90,
            shadow=True)

plt.title('Persentase kriminalitas dengan kategori mayor pada tahun 2014 di Seluruh wilayah London', size=18)
# Out:
# Text(0.5, 1.0, 'Persentase kriminalitas dengan kategori mayor pada tahun 2014 di Seluruh wilayah London')

# %% [markdown]
# Dari piechart diatas dapat disimpulkan bahwa Persentase kriminalitas dengan kategori mayor pada tahun 2014 di Seluruh wilayah London, kasus Theft and Handling menduduki posisi teratas dalam kategori mayor dengan persentase 32,97% dan Other Notifiable Offences mempunyai persentase terkecil yaitu 2,63%

# %% [markdown]
# **PERTANYAAN 7** : Berapa banyak kriminalitas dengan kategori Common Assault dari tahun 2011 sampai 2016?

# %% [markdown]
# **BOX PLOT**

# %%
df_7 = kriminalitas[kriminalitas['year'] >= 2011]
df_7
# Out:
#           lsoa_code     borough               major_category  \
# 9         E01004177      Sutton           Theft and Handling
# 24        E01001301      Ealing           Theft and Handling
# 25        E01001794     Hackney  Violence Against the Person
# 32        E01000733     Bromley              Criminal Damage
# 43        E01001193     Croydon           Theft and Handling
# ...             ...         ...                          ...
# 13490580  E01003154     Lambeth                     Burglary
# 13490584  E01003301    Lewisham  Violence Against the Person
# 13490590  E01001679   Greenwich           Theft and Handling
# 13490592  E01033327    Lewisham  Violence Against the Person
# 13490600  E01002504  Hillingdon                      Robbery
#
#                             minor_category  value  year  month
# 9              Theft/Taking of Pedal Cycle      1  2016      8
# 24                      Other Theft Person      2  2012      1
# ...

# %%
df_7.drop(['month','lsoa_code','borough','month','major_category'], axis=1, inplace=True)
df_7
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_51948\3414298540.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_7.drop(['month','lsoa_code','borough','month','major_category'], axis=1, inplace=True)
#                             minor_category  value  year
# 9              Theft/Taking of Pedal Cycle      1  2016
# 24                      Other Theft Person      2  2012
# 25                              Harassment      1  2013
# 32        Criminal Damage To Motor Vehicle      1  2016
# 43                             Other Theft      1  2014
# ...                                    ...    ...   ...
# 13490580            Burglary in a Dwelling      3  2015
# 13490584               Assault with Injury      1  2015
# 13490590     Theft/Taking Of Motor Vehicle      1  2012
# ...

# %%
df_7 = df_7[df_7['minor_category'] == 'Common Assault']
df_7
# Out:
#           minor_category  value  year
# 120       Common Assault      1  2014
# 291       Common Assault      3  2014
# 302       Common Assault      3  2014
# 309       Common Assault      1  2015
# 380       Common Assault      1  2013
# ...                  ...    ...   ...
# 13490379  Common Assault      1  2016
# 13490380  Common Assault      4  2013
# 13490388  Common Assault      1  2011
# 13490439  Common Assault      3  2016
# 13490592  Common Assault      2  2013
#
# [160362 rows x 3 columns]

# %%
df_7['year'].value_counts()
# Out:
# 2016    31306
# 2015    30621
# 2014    27763
# 2011    23898
# 2012    23649
# 2013    23125
# Name: year, dtype: int64

# %%
area_array = np.array([['2011', '2012','2013', '2014', '2015', '2016'], [23898, 23649, 23125, 27763, 30621, 31306]])
area_array = area_array.T
area_array

df_7 = pd.DataFrame(area_array, columns = ['tahun', 'minor_category'])
df_7
# Out:
#   tahun minor_category
# 0  2011          23898
# 1  2012          23649
# 2  2013          23125
# 3  2014          27763
# 4  2015          30621
# 5  2016          31306

# %%
df_7.set_index('tahun',inplace=True)
df_7
# Out:
#       minor_category
# tahun
# 2011           23898
# 2012           23649
# 2013           23125
# 2014           27763
# 2015           30621
# 2016           31306

# %%
df_7.describe()
# Out:
#        minor_category
# count        6.000000
# mean     26727.000000
# std       3678.464408
# min      23125.000000
# 25%      23711.250000
# 50%      25830.500000
# 75%      29906.500000
# max      31306.000000

# %%
df_7.index = df_7.index.map(str)
df_7['minor_category'] = df_7['minor_category'].map(int)

df_7.plot(kind='box',
          figsize =(10,7),
          color = 'black',
          vert = False)

plt.title('Jumlah kriminalitas dengan kategori Common Assault dari tahun 2011 sampai 2016', size=16)
plt.xlabel('Jumlah Kriminalitas', size=14)
# Out:
# Text(0.5, 0, 'Jumlah Kriminalitas')

# %% [markdown]
# Dari boxplot diatas bisa kita simpulkan bahwa data kasus kriminalitas dengan kategori Common Assault dari tahun 2011 sampai 2016 memiliki rerata 26727 dengan nilai minimal 23125, Q1 = 23711, Q2 atau median = 25831.5, Q3 = 29906.5 dan nilai maximumnya 31306.

# %% [markdown]
# **OVERALL ANALYSIS**

# %% [markdown]
# Berdasarkan kesimpulan secara umum, Kasus Kriminalitas di kota London berbanding lurus seiring bertambahnya waktu. Hal tersebut dapat dibuktikan pada Line Plot dan Scatter Plot. Pernyataan tersebut ini juga dapat menjawab hipotesis yang artinya hipotesis dapat diterima
